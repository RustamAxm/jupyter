# %%
import numpy as np
import pandas as pd
print("загрузка библиотек")
# Out:
# загрузка библиотек

# %%
student_performance = pd.read_csv(r'C:\Users\Rusta\YandexDisk\Jupiter_notebook\StudentsPerformance.csv')

# %%
student_performance.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_performance.iloc[0:3,0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
student_performance.iloc[[0, 3, 10], [0, 5, -4]]
# Out:
#     gender  math score test preparation course
# 0   female          72                    none
# 3     male          47                    none
# 10    male          58                    none

# %%
student_performance_names = student_performance.iloc[[0, 3, 4, 7, 8]]

# %%
student_performance_names.index = ["A", "B", "C", "D", "F"]

# %%
student_performance_names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# A  female        group B           bachelor's degree      standard
# B    male        group A          associate's degree  free/reduced
# C    male        group C                some college      standard
# D    male        group B                some college  free/reduced
# F    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# A                    none          72             72             74
# B                    none          47             57             44
# C                    none          76             78             75
# D                    none          40             43             39
# F               completed          64             64             67

# %%
student_performance_names.loc[["A", "B"], ["gender", "writing score"]]
# Out:
#    gender  writing score
# A  female             74
# B    male             44

# %%
student_performance_names.iloc[:, 0]
# Out:
# A    female
# B      male
# C      male
# D      male
# F      male
# Name: gender, dtype: object

# %%
series_1 = pd.Series([1,2,3], index=['A', 'B', 'C'])
series_2 = pd.Series([4,5,6], index=['A', 'B', 'C'])

# %%
pd.DataFrame({"col_name_1":series_1, "col_name_2":series_2})
# Out:
#    col_name_1  col_name_2
# A           1           4
# B           2           5
# C           3           6

# %%
student_performance_names[{"gender"}]
# Out:
#    gender
# A  female
# B    male
# C    male
# D    male
# F    male

# %%
student_performance.loc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student_performance.dtypes.value_counts()
# Out:
# object    5
# int64     3
# dtype: int64

# %%
titan = pd.read_csv(r'C:\Users\Rusta\YandexDisk\Jupiter_notebook\titanic.csv')

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
student_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
mean_writing_score =student_performance["writing score"].mean()

# %%
mean_writing_score
# Out:
# 68.054

# %%
student_performance.loc[student_performance["writing score"] >mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_performance[(student_performance['writing score'] > mean_writing_score) & (student_performance.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
query = (student_performance['writing score'] > mean_writing_score) & (student_performance.gender == 'female')

# %%
query
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
student_performance.loc[query].head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 12  female        group B                 high school      standard
# 15  female        group C            some high school      standard
# 21  female        group B                some college  free/reduced
# 23  female        group C            some high school      standard
# 27  female        group C           bachelor's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 1                completed          69             90             88
# ...

# %%
query_1 = (student_performance['lunch'] == "free/reduced")

# %%
student_performance.loc[query_1].shape[0]/student_performance.shape[0]
# Out:
# 0.355

# %%
student_performance.loc[query_1].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
query_2 = (student_performance['lunch'] == "standard")

# %%
student_performance.loc[query_2].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
student_performance = student_performance.rename(columns = {'parental level of education' : 'parental_level_of_education',
                                                           'test preparation course': 'test_preparation_course',
                                                           'math score': 'math_score',
                                                           'reading score': "reading_score",
                                                           'writing score': 'writing_score'})

# %%
student_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_performance.query("gender == 'female'& writing_score > 78" )
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
[i for i in list(student_performance) if 'score' in i]
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
student_performance.filter(like  = 'score').head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
student_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
mean_scores = student_performance.groupby(['gender', 'race/ethnicity'], as_index = False)\
.aggregate({"math_score": 'mean', "reading_score": 'mean'})\
.rename(columns = {'math_score':'mean_math', 'reading_score': 'mean_reading'})

# %%
mean_scores
# Out:
#    gender race/ethnicity  mean_math  mean_reading
# 0  female        group A  58.527778     69.000000
# 1  female        group B  61.403846     71.076923
# 2  female        group C  62.033333     71.944444
# 3  female        group D  65.248062     74.046512
# 4  female        group E  70.811594     75.840580
# 5    male        group A  63.735849     61.735849
# 6    male        group B  65.930233     62.848837
# 7    male        group C  67.611511     65.424460
# 8    male        group D  69.413534     66.135338
# 9    male        group E  76.746479     70.295775

# %%
student_performance.sort_values(["gender", "math_score"],  ascending = False)\
.groupby('gender').head(10)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 104    male        group C                some college      standard
# 934    male        group C          associate's degree      standard
# 34     male        group E                some college      standard
# 286    male        group E          associate's degree      standard
# 539    male        group A          associate's degree      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# ...

# %%
student_performance["total_score"] = student_performance.writing_score + student_performance.math_score + student_performance.reading_score

# %%
student_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
student_performance = student_performance.assign(total_score_log = np.log(student_performance.total_score))

# %%
student_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
student_performance.drop(['total_score'], axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota = pd.read_csv(r'C:\Users\Rusta\YandexDisk\Jupiter_notebook\dota_hero_stats.csv')

# %%
query_3 = (dota['legs'] == 8)

# %%
dota.loc[query_3].shape
# Out:
# (1, 8)

# %%
dota.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
dota.legs.value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
zp = pd.read_csv("https://stepik.org/media/attachments/course/4852/accountancy.csv", index_col = 0)

# %%
zp.head(6)
# Out:
#   Executor Type  Salary
# 0     Pupa    D      63
# 1     Pupa    A     158
# 2     Pupa    D     194
# 3     Pupa    E     109
# 4    Loopa    E     184
# 5    Loopa    F     232

# %%
zp.groupby(['Executor', 'Type']).aggregate({'Salary': 'mean'})
# Out:
#                    Salary
# Executor Type
# Loopa    A      58.000000
#          B     145.166667
#          C     154.333333
#          D     137.714286
#          E     164.000000
#          F     238.000000
# Pupa     A     160.833333
#          B      77.000000
#          C      74.500000
#          D     146.500000
#          E     131.200000
#          F     136.250000

# %%
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
(dota.attack_type +'_' + dota.primary_attr).value_counts()
# Out:
# Ranged_int    40
# Melee_str     35
# Melee_agi     19
# Ranged_agi    18
# Ranged_str     3
# Melee_int      2
# dtype: int64

# %%
data = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
data.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
data.groupby('genus').aggregate({'sucrose': 'mean', 'alanin': 'mean', \
                                'citrate':'mean', 'glucose': 'mean', \
                                'oleic_acid': 'mean'})
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
data.groupby(['genus']).aggregate({'alanin': ['min', 'mean', 'max']}).loc[['Fucus']].round(2)
# Out:
#       alanin
#          min  mean   max
# genus
# Fucus   0.35  3.57  6.64

# %%
data.query('genus == "Fucus"').describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165

# %%
data.groupby(['group']).describe()
# Out:
#       sucrose                                                             \
#         count      mean       std       min       25%      50%       75%
# group
# brown     6.0  4.709666  2.336471  1.636122  3.070321  5.00397  6.773014
# green     3.0  4.008792  1.634817  2.452623  3.157047  3.86147  4.786877
# red       1.0  0.704580       NaN  0.704580  0.704580  0.70458  0.704580
#
#                 alanin            ...   glucose           oleic_acid  \
#             max  count      mean  ...       75%       max      count
# group                             ...
# brown  6.825467    6.0  3.103846  ...  3.866782  6.013219        6.0
# green  5.712284    3.0  3.997055  ...  3.041936  3.343707        3.0
# red    0.704580    1.0  3.176440  ...  3.242090  3.242090        1.0
#
#
#            mean       std       min       25%       50%       75%       max
# group
# brown  3.584995  2.094095  0.304573  2.672695  3.774952  4.652528  6.405165
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
student_performance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
student_performance.plot.scatter(x = 'math_score', y = 'reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
sns.lmplot(x = 'math_score', y = 'reading_score', hue = 'gender', data = student_performance, fit_reg=False)

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
data_1 = pd.read_csv(r'C:\Users\Rusta\YandexDisk\Jupiter_notebook\dataset_209770_6.txt', sep=' ')

# %%
data_1
# Out:
#               x            y
# 0   1409.981779  1297.029997
# 1    600.667930   807.268839
# 2   1297.061337   585.840117
# 3   1391.806526  1293.043502
# 4   1298.943394   612.531891
# ..          ...          ...
# 95   711.294684   990.921934
# 96   806.825642   288.584016
# 97   400.224564  1193.295064
# 98  1401.398479  1301.336426
# 99   501.636305   705.535106
#
# [100 rows x 2 columns]

# %%
sns.lmplot(x='x', y='y', data = data_1)

# %%
data_2 = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

# %%
g=sns.heatmap(data_2, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
data = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
data['cnt'] = data.roles.str.count(',')+1

# %%
data.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles  cnt
# 0                       ['Carry', 'Escape', 'Nuker']    3
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']    4
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']    4
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...    5
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']    4

# %%
data.cnt.hist()
# Out:
# <AxesSubplot:>

# %%
flover = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)

# %%
flover.head(5)
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
ax = sns.violinplot(y="petal length", data = flover)

# %%
sns.pairplot(flover, hue = 'species')

# %%
my_data = pd.DataFrame({'type' : ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]})

# %%
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
my_stat =pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv').loc[:19]

# %%
my_stat
# Out:
#     V1    V2 V3   V4
# 0    2  13.0  B  1.0
# 1   -1   7.0  B  1.0
# 2    0  11.0  A  0.0
# 3    2  11.0  A  2.0
# 4    0  10.0  B -1.0
# 5    2  11.0  A  0.0
# 6    0   9.0  A  2.0
# 7    1   9.0  A  1.0
# 8    0   9.0  B  2.0
# 9   -1  10.0  A  0.0
# 10   1  10.0  A  1.0
# 11  -2  10.0  A  1.0
# 12   0   8.0  B  0.0
# 13   1  12.0  A  3.0
# 14  -1  10.0  A  2.0
# 15   2  10.0  B  1.0
# 16   0   9.0  B  1.0
# 17   0  11.0  A  0.0
# 18   0   8.0  A  1.0
# 19   0  10.0  A  1.0

# %%
 subset_1 =my_stat.drop(['V2', 'V4'], axis=1).loc[:19]

# %%
 subset_1
# Out:
#     V1 V3
# 0    2  B
# 1   -1  B
# 2    0  A
# 3    2  A
# 4    0  B
# 5    2  A
# 6    0  A
# 7    1  A
# 8    0  B
# 9   -1  A
# 10   1  A
# 11  -2  A
# 12   0  B
# 13   1  A
# 14  -1  A
# 15   2  B
# 16   0  B
# 17   0  A
# 18   0  A
# 19   0  A

# %%
 subset_2 =my_stat.drop([1, 5], axis=0).drop(['V2', 'V3'], axis=1)

# %%
 subset_2
# Out:
#     V1   V4
# 0    2  1.0
# 2    0  0.0
# 3    2  2.0
# 4    0 -1.0
# 6    0  2.0
# 7    1  1.0
# 8    0  2.0
# 9   -1  0.0
# 10   1  1.0
# 11  -2  1.0
# 12   0  0.0
# 13   1  3.0
# 14  -1  2.0
# 15   2  1.0
# 16   0  1.0
# 17   0  0.0
# 18   0  1.0
# 19   0  1.0

# %%
df =pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat = df.iloc[:20]
subset_1 =df.drop(['V2', 'V4'], axis=1).iloc[:10]
subset_2 =df.drop([1, 5], axis=0).drop(['V1', 'V3'], axis=1)

# %%
subset_2
# Out:
#        V2   V4
# 0    13.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 4    10.0 -1.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
my_stat = df.iloc[:20]
subset_1 =df.iloc[:10, [0, 2]]
subset_2 =df.iloc[:,[1,3]].drop(df.index[[1,5]])

# %%
subset_2
# Out:
#        V2   V4
# 0    13.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 4    10.0 -1.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
subset_1 =my_stat.drop(['V2', 'V4'], axis=1).loc[:9]
subset_2 =my_stat.drop([0, 4], axis=0).drop(['V1', 'V3'], axis=1)

# %%
subset_1 = my_stat.query('V1>0 and V3 == "A"')
subset_2 = my_stat.query('V2 != 10 or V4 >= 1')
subset_1
subset_2
# Out:
#     V1    V2 V3   V4
# 0    2  13.0  B  1.0
# 1   -1   7.0  B  1.0
# 2    0  11.0  A  0.0
# 3    2  11.0  A  2.0
# 5    2  11.0  A  0.0
# 6    0   9.0  A  2.0
# 7    1   9.0  A  1.0
# 8    0   9.0  B  2.0
# 10   1  10.0  A  1.0
# 11  -2  10.0  A  1.0
# 12   0   8.0  B  0.0
# 13   1  12.0  A  3.0
# 14  -1  10.0  A  2.0
# 15   2  10.0  B  1.0
# 16   0   9.0  B  1.0
# 17   0  11.0  A  0.0
# 18   0   8.0  A  1.0
# 19   0  10.0  A  1.0

# %%
my_stat = my_stat.assign(V5 = my_stat.V1+my_stat.V4, V6 = np.log(my_stat.V2))
my_stat
# Out:
#     V1    V2 V3   V4   V5        V6
# 0    2  13.0  B  1.0  3.0  2.564949
# 1   -1   7.0  B  1.0  0.0  1.945910
# 2    0  11.0  A  0.0  0.0  2.397895
# 3    2  11.0  A  2.0  4.0  2.397895
# 4    0  10.0  B -1.0 -1.0  2.302585
# 5    2  11.0  A  0.0  2.0  2.397895
# 6    0   9.0  A  2.0  2.0  2.197225
# 7    1   9.0  A  1.0  2.0  2.197225
# 8    0   9.0  B  2.0  2.0  2.197225
# 9   -1  10.0  A  0.0 -1.0  2.302585
# 10   1  10.0  A  1.0  2.0  2.302585
# 11  -2  10.0  A  1.0 -1.0  2.302585
# 12   0   8.0  B  0.0  0.0  2.079442
# 13   1  12.0  A  3.0  4.0  2.484907
# 14  -1  10.0  A  2.0  1.0  2.302585
# 15   2  10.0  B  1.0  3.0  2.302585
# 16   0   9.0  B  1.0  1.0  2.197225
# 17   0  11.0  A  0.0  0.0  2.397895
# 18   0   8.0  A  1.0  1.0  2.079442
# 19   0  10.0  A  1.0  1.0  2.302585

# %%
my_stat = my_stat.rename(columns={'V1' : "session_value", 'V2' : "group", 'V3' : "time", 'V4' : "n_users"})
my_stat
# Out:
#     session_value  group time  n_users   V5        V6
# 0               2   13.0    B      1.0  3.0  2.564949
# 1              -1    7.0    B      1.0  0.0  1.945910
# 2               0   11.0    A      0.0  0.0  2.397895
# 3               2   11.0    A      2.0  4.0  2.397895
# 4               0   10.0    B     -1.0 -1.0  2.302585
# 5               2   11.0    A      0.0  2.0  2.397895
# 6               0    9.0    A      2.0  2.0  2.197225
# 7               1    9.0    A      1.0  2.0  2.197225
# 8               0    9.0    B      2.0  2.0  2.197225
# 9              -1   10.0    A      0.0 -1.0  2.302585
# 10              1   10.0    A      1.0  2.0  2.302585
# 11             -2   10.0    A      1.0 -1.0  2.302585
# 12              0    8.0    B      0.0  0.0  2.079442
# 13              1   12.0    A      3.0  4.0  2.484907
# 14             -1   10.0    A      2.0  1.0  2.302585
# 15              2   10.0    B      1.0  3.0  2.302585
# ...

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat = my_stat.rename(columns={'V1' : "session_value", 'V2' : "group", 'V3' : "time", 'V4' : "n_users"})
my_stat.session_value.fillna(0)
M = my_stat[my_stat.n_users > 0.0].n_users.median()
M
# Out:
# 1.0

# %%
my_stat.loc[my_stat['n_users'] < 0, 'n_users'] = M
my_stat.head(30)
# Out:
#     session_value  group time  n_users
# 0               2   13.0    B      1.0
# 1              -1    7.0    B      1.0
# 2               0   11.0    A      0.0
# 3               2   11.0    A      2.0
# 4               0   10.0    B      1.0
# 5               2   11.0    A      0.0
# 6               0    9.0    A      2.0
# 7               1    9.0    A      1.0
# 8               0    9.0    B      2.0
# 9              -1   10.0    A      0.0
# 10              1   10.0    A      1.0
# 11             -2   10.0    A      1.0
# 12              0    8.0    B      0.0
# 13              1   12.0    A      3.0
# 14             -1   10.0    A      2.0
# 15              2   10.0    B      1.0
# 16              0    9.0    B      1.0
# 17              0   11.0    A      0.0
# 18              0    8.0    A      1.0
# 19              0   10.0    A      1.0
# 20              1   10.0    B      2.0
# 21              3   10.0    A      2.0
# 22             -2   12.0    A      3.0
# ...

# %%
mean_session_value_data = my_stat.groupby('group', as_index=False ).agg({'session_value': 'mean'}).rename(columns ={ 'session_value' : 'mean_session_value'})
mean_session_value_data
# Out:
#    group  mean_session_value
# 0    5.0            0.000000
# 1    7.0            0.333333
# 2    8.0            0.633333
# 3    9.0            0.238938
# 4   10.0            0.065990
# 5   11.0           -0.081081
# 6   12.0           -0.078947
# 7   13.0            0.000000

# %%
submission_data = pd.read_csv("https://stepik.org/media/attachments/course/4852/event_data_train.zip")
submission_data.head()
# Out:
#    step_id   timestamp      action  user_id
# 0    32815  1434340848      viewed    17632
# 1    32815  1434340848      passed    17632
# 2    32815  1434340848  discovered    17632
# 3    32811  1434340895  discovered    17632
# 4    32811  1434340895      viewed    17632

# %%
submission_data['date'] = pd.to_datetime(submission_data.timestamp,unit="s")

# %%
submission_data.head()
# Out:
#    step_id   timestamp      action  user_id                date
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35

# %%
gap_date = submission_data[["user_id", "date", "timestamp"]].drop_duplicates(subset=["user_id", "date"])\
.groupby("user_id")["timestamp"].apply(list).head()\
.apply(np.diff).values

# %%
gap_data=pd.Series(np.concatenate(gap_date, axis=0))
